# %%
pip install numpy pandas scikit-learn matplotlib
# Out:
# Requirement already satisfied: numpy in c:\users\janus\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: pandas in c:\users\janus\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: scikit-learn in c:\users\janus\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: matplotlib in c:\users\janus\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\janus\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\janus\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\janus\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\janus\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\janus\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\janus\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\janus\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\janus\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\janus\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\janus\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\janus\anaconda3\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\janus\anaconda3\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\janus\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\janus\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importar bibliotecas
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
# Datos (Tamaño en m², Precio en USD)
data1 = {
    'Tamaño': [10,40, 50, 60, 70, 80, 45, 55, 65, 75, 85, 90, 95, 100, 110, 120, 130, 140, 150, 160, 170, 180, 190, 200, 210, 220, 230, 240, 250, 260, 270],
    'Precio': [20,100, 150, 180, 220, 260, 130, 160, 190, 210, 250, 280, 300, 320, 340, 360, 380, 400, 420, 440, 460, 480, 500, 520, 540, 560, 580, 600, 620, 640, 660]
}

# %%
# Datos (Tamaño en m², Precio en USD)
data1 = {
    'Tamaño': [10,40, 50, 60, 70, 80, 45, 55, 65, 75, 85, 90, 95, 100, 110, 120, 130, 140, 150, 160, 170, 180, 190, 200, 210, 220, 230, 240, 250, 260, 270],
    'Precio': [20,100, 150, 180, 220, 260, 130, 160, 190, 210, 250, 280, 300, 320, 340, 360, 380, 400, 420, 440, 460, 480, 500, 520, 540, 560, 580, 600, 620, 640, 660]
}

# %%
# Convertir los datos en un DataFrame
df = pd.DataFrame(data1)

# Variables independientes (Tamaño y Habitaciones) y dependiente (Precio)
X = df[['Tamaño']]
y = df['Precio']

# Crear un modelo de regresión lineal
modelo = LinearRegression()

# Ajustar el modelo a los datos
modelo.fit(X, y)

# Coeficientes de la regresión
beta_0 = modelo.intercept_  # Intercepto
beta_1 = modelo.coef_  # Pendientes (Tamaño y Habitaciones)

# Mostrar los coeficientes
print(f"Intercepto (β0): {beta_0}")
print(f"Coeficiente (Tamaño, β1): {beta_1}")

# Visualizar la regresión (opcional para datos simples)
plt.scatter(df['Tamaño'], y, color='blue', label='Datos Reales')
plt.plot(df['Tamaño'], modelo.predict(X), color='red', label='Línea de Regresión')
plt.title('Regresión Lineal: Precio vs Tamaño')
plt.xlabel('Tamaño (m²)')
plt.ylabel('Precio (USD)')
plt.legend()
plt.show()
# Out:
# Intercepto (β0): 46.42816510311707
# Coeficiente (Tamaño, β1): [2.36884985]

# %%
# Predecir precios para dos nuevos valores
nuevo_X = np.array([[55], [65]])  # Nuevos valores (Tamaño, Habitaciones)
predicciones = modelo.predict(nuevo_X)

# Mostrar las predicciones
print("\nPredicciones:")
for i, pred in enumerate(predicciones):
    print(f"Predicción {i+1} para (Tamaño: {nuevo_X[i][0]} m²): {pred:.2f} USD")
# Out:
# Predicciones:
# Predicción 1 para (Tamaño: 55 m²): 176.71 USD
# Predicción 2 para (Tamaño: 65 m²): 200.40 USD
# C:\Users\Janus\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
